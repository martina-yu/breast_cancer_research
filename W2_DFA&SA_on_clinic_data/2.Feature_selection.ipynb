# %%
import pandas as pd
import numpy as np
from lifelines import CoxPHFitter
import warnings

# %%
sig_gene = pd.read_excel('./survival_results/multivariate_cox_summary_25_MAD.xlsx')

# %%
sig_gene
# Out:
#            coef      exp(coef)  se(coef)           z      Pr(>|z|)
# 0   -121.193305   2.324965e-53  5.983061  -20.256069  3.140576e-91
# 1    -19.604738   3.060346e-09  3.299911   -5.940990  2.833060e-09
# 2    -58.606728   3.527130e-26  1.246601  -47.013236  0.000000e+00
# 3    341.725671  2.567870e+148  2.973437  114.926148  0.000000e+00
# 4   -244.220108  8.640818e-107  3.725527  -65.553179  0.000000e+00
# ..          ...            ...       ...         ...           ...
# 250    0.000000   1.000000e+00  3.368858    0.000000  1.000000e+00
# 251    0.000000   1.000000e+00  1.286101    0.000000  1.000000e+00
# 252    0.000000   1.000000e+00  5.531808    0.000000  1.000000e+00
# 253    0.000000   1.000000e+00  2.111269    0.000000  1.000000e+00
# 254    0.000000   1.000000e+00  0.221609    0.000000  1.000000e+00
#
# [255 rows x 5 columns]
